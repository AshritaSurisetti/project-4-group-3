# %% [markdown]
# # Project 4 - Group 3 (Ashrita Surisetti, Ali Yazan, Malini Sintre)
# # Introduction

# %% [markdown]
# ### Clean-up of Dataset A

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df=pd.read_csv('Resources/2019-Nov.csv', encoding='utf-8')
df.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-11-01 00:00:00 UTC       view     1003461  2053013555631882655
# 1  2019-11-01 00:00:00 UTC       view     5000088  2053013566100866035
# 2  2019-11-01 00:00:01 UTC       view    17302664  2053013553853497655
# 3  2019-11-01 00:00:01 UTC       view     3601530  2053013563810775923
# 4  2019-11-01 00:00:01 UTC       view     1004775  2053013555631882655
#
#                category_code   brand   price    user_id  \
# 0     electronics.smartphone  xiaomi  489.07  520088904
# 1  appliances.sewing_machine  janome  293.65  530496790
# 2                        NaN   creed   28.31  561587266
# 3  appliances.kitchen.washer      lg  712.87  518085591
# 4     electronics.smartphone  xiaomi  183.27  558856683
#
#                            user_session
# 0  4d3b30da-a5e4-49df-b1a8-ba5943f1dd33
# 1  8e5f4f83-366c-4f70-860e-ca7417414283
# 2  755422e7-9040-477b-9bd2-6a6e8fd97387
# 3  3bfb58cd-7892-48cc-8020-2f17e6de6e7f
# 4  313628f1-68b8-460d-84f6-cec7a8796ef2

# %%
memory_usage_mb = df.memory_usage(deep=True).sum() / (1024 * 1024)
print("Memory usage of df:", memory_usage_mb, "MB")
# Out:
# Memory usage of df: 25028.222966194153 MB

# %%
num_rows = df.shape[0]
num_rows
# Out:
# 67501979

# %%
#Dropping user_session 
df = df.drop(columns='user_session')
#Dropping No value cells 
df_cleaned = df.dropna()
# Reset index
df_cleaned = df_cleaned.reset_index(drop=True)

# %%
num_rows_cleaned = df_cleaned.shape[0]
num_rows_cleaned
# Out:
# 42089570

# %%
memory_usage_mb = df_cleaned.memory_usage(deep=True).sum() / (1024 * 1024)
print("Memory usage of df_cleaned:", memory_usage_mb, "MB")
# Out:
# Memory usage of df_cleaned: 12652.161519050598 MB

# %%
# Converting event_time to datetime
try:
    df_cleaned['event_time'] = pd.to_datetime(df_cleaned['event_time'], format='%Y-%m-%d %H:%M:%S %Z', errors='coerce')
except Exception as e:
    print("Error during conversion:", e)

# %%
# Print data types of each column
print("Data types of each column:")
print(df_cleaned.dtypes)
print()
# Out:
# Data types of each column:
# event_time       datetime64[ns, UTC]
# event_type                    object
# product_id                     int64
# category_id                    int64
# category_code                 object
# brand                         object
# price                        float64
# user_id                        int64
# dtype: object

# %%
# Renaming columns
df_cleaned = df_cleaned.rename(columns={
    'event_time': 'Timestamp',
    'event_type': 'Visitor_Action',
    'product_id': 'Product',
    'category_id': 'Product_Category',
    'category_code': 'Category_Name',
    'brand': 'Brand',
    'price': 'Price',
    'user_id': 'Visitor_ID'
})
df_cleaned
# Out:
#                          Timestamp Visitor_Action   Product  \
# 0        2019-11-01 00:00:00+00:00           view   1003461
# 1        2019-11-01 00:00:00+00:00           view   5000088
# 2        2019-11-01 00:00:01+00:00           view   3601530
# 3        2019-11-01 00:00:01+00:00           view   1004775
# 4        2019-11-01 00:00:01+00:00           view   1306894
# ...                            ...            ...       ...
# 42089565 2019-11-30 23:59:57+00:00           view  12301059
# 42089566 2019-11-30 23:59:58+00:00           view  28719425
# 42089567 2019-11-30 23:59:59+00:00           view   1004833
# 42089568 2019-11-30 23:59:59+00:00           view   2701706
# 42089569 2019-11-30 23:59:59+00:00           view   1004233
#
#              Product_Category                     Category_Name    Brand  \
# 0         2053013555631882655            electronics.smartphone   xiaomi
# 1         2053013566100866035         appliances.sewing_machine   janome
# 2         2053013563810775923         appliances.kitchen.washer       lg
# 3         2053013555631882655            electronics.smartphone   xiaomi
# 4         2053013558920217191                computers.notebook       hp
# ...                       ...                               ...      ...
# 42089565  2053013556311359947          construction.tools.drill    bosch
# 42089566  2053013565639492569                     apparel.shoes    baden
# 42089567  2053013555631882655            electronics.smartphone  samsung
# 42089568  2053013563911439225  appliances.kitchen.refrigerators  samsung
# 42089569  2053013555631882655            electronics.smartphone    apple
#
#             Price  Visitor_ID
# 0          489.07   520088904
# 1          293.65   530496790
# 2          712.87   518085591
# 3          183.27   558856683
# 4          360.09   520772685
# ...           ...         ...
# 42089565   266.16   562661595
# 42089566    62.81   545223467
# 42089567   167.03   557794415
# 42089568   566.27   531607492
# 42089569  1312.52   579969851
#
# [42089570 rows x 8 columns]

# %%
# Extract day of the week (Monday=0, Sunday=6) and day of the month
df_cleaned.loc[:, 'Day_of_Week'] = df_cleaned['Timestamp'].dt.dayofweek
df_cleaned.loc[:, 'Day_of_Month'] = df_cleaned['Timestamp'].dt.day

df_cleaned = df_cleaned[['Timestamp','Day_of_Week','Day_of_Month','Visitor_ID','Visitor_Action','Product','Product_Category','Category_Name','Brand','Price']]
df_cleaned
# Out:
#                          Timestamp  Day_of_Week  Day_of_Month  Visitor_ID  \
# 0        2019-11-01 00:00:00+00:00            4             1   520088904
# 1        2019-11-01 00:00:00+00:00            4             1   530496790
# 2        2019-11-01 00:00:01+00:00            4             1   518085591
# 3        2019-11-01 00:00:01+00:00            4             1   558856683
# 4        2019-11-01 00:00:01+00:00            4             1   520772685
# ...                            ...          ...           ...         ...
# 42089565 2019-11-30 23:59:57+00:00            5            30   562661595
# 42089566 2019-11-30 23:59:58+00:00            5            30   545223467
# 42089567 2019-11-30 23:59:59+00:00            5            30   557794415
# 42089568 2019-11-30 23:59:59+00:00            5            30   531607492
# 42089569 2019-11-30 23:59:59+00:00            5            30   579969851
#
#          Visitor_Action   Product     Product_Category  \
# 0                  view   1003461  2053013555631882655
# 1                  view   5000088  2053013566100866035
# 2                  view   3601530  2053013563810775923
# 3                  view   1004775  2053013555631882655
# 4                  view   1306894  2053013558920217191
# ...                 ...       ...                  ...
# 42089565           view  12301059  2053013556311359947
# 42089566           view  28719425  2053013565639492569
# 42089567           view   1004833  2053013555631882655
# 42089568           view   2701706  2053013563911439225
# 42089569           view   1004233  2053013555631882655
#
#                              Category_Name    Brand    Price
# 0                   electronics.smartphone   xiaomi   489.07
# 1                appliances.sewing_machine   janome   293.65
# 2                appliances.kitchen.washer       lg   712.87
# 3                   electronics.smartphone   xiaomi   183.27
# 4                       computers.notebook       hp   360.09
# ...                                    ...      ...      ...
# 42089565          construction.tools.drill    bosch   266.16
# 42089566                     apparel.shoes    baden    62.81
# 42089567            electronics.smartphone  samsung   167.03
# 42089568  appliances.kitchen.refrigerators  samsung   566.27
# 42089569            electronics.smartphone    apple  1312.52
#
# [42089570 rows x 10 columns]

# %%
#rounding up the prices - no decimal points
df_cleaned.loc[:,'Price'] = df_cleaned['Price'].round(decimals=0)
# List unique values with counts for categorical columns
for column in df_cleaned.select_dtypes(include='object'):
    print(f"Unique values for {column}:")
    print(df_cleaned[column].value_counts())
    print()
# Out:
# Unique values for Visitor_Action:
# Visitor_Action
# view        39315226
# cart         2115088
# purchase      659256
# Name: count, dtype: int64
#
# Unique values for Category_Name:
# Category_Name
# electronics.smartphone          16353582
# electronics.video.tv             2195119
# computers.notebook               2164657
# electronics.clocks               1811325
# electronics.audio.headphone      1803895
#                                   ...
# apparel.shorts                       447
# construction.tools.screw             157
# appliances.kitchen.fryer             105
# country_yard.furniture.bench           2
# apparel.jacket                         1
# Name: count, Length: 129, dtype: int64
#
# Unique values for Brand:
# Brand
# samsung       7733328
# apple         6213902
# xiaomi        4138112
# huawei        1384154
# lg            1024251
#                ...
# kolpasan            1
# emily               1
# zazu                1
# powerplant          1
# invotone            1
# Name: count, Length: 1987, dtype: int64

# %%
visitor_id_counts = df_cleaned['Visitor_ID'].value_counts()
visitor_id_counts
# Out:
# Visitor_ID
# 569335945    12644
# 568778435     8829
# 512365995     5982
# 512475445     4799
# 568804062     4179
#              ...
# 566542118        1
# 517039044        1
# 573045499        1
# 573047848        1
# 579969851        1
# Name: count, Length: 2862935, dtype: int64

# %%
# Get unique user IDs with "view" events
view_users = df_cleaned[df_cleaned['Visitor_Action'] == 'view']['Visitor_ID'].unique()

# Get unique user IDs with "cart" or "purchase" events
cart_purchase_users = df_cleaned[df_cleaned['Visitor_Action'].isin(['cart', 'purchase'])]['Visitor_ID'].unique()

# Find user IDs with both "view" and "cart" or "purchase" events
view_and_cart_purchase_users = set(view_users) & set(cart_purchase_users)

# Filter the dataset to include only rows for user IDs with both "view" and "cart" or "purchase" events
filtered_df = df_cleaned[df_cleaned['Visitor_ID'].isin(view_and_cart_purchase_users)]

filtered_df = filtered_df.reset_index(drop=True)

# Print the filtered DataFrame
filtered_df
# Out:
#                          Timestamp  Day_of_Week  Day_of_Month  Visitor_ID  \
# 0        2019-11-01 00:00:01+00:00            4             1   518085591
# 1        2019-11-01 00:00:02+00:00            4             1   532647354
# 2        2019-11-01 00:00:05+00:00            4             1   526595547
# 3        2019-11-01 00:00:10+00:00            4             1   513741043
# 4        2019-11-01 00:00:14+00:00            4             1   549256216
# ...                            ...          ...           ...         ...
# 23772862 2019-11-30 23:59:49+00:00            5            30   514720898
# 23772863 2019-11-30 23:59:53+00:00            5            30   513558661
# 23772864 2019-11-30 23:59:58+00:00            5            30   545223467
# 23772865 2019-11-30 23:59:59+00:00            5            30   557794415
# 23772866 2019-11-30 23:59:59+00:00            5            30   531607492
#
#          Visitor_Action   Product     Product_Category  \
# 0                  view   3601530  2053013563810775923
# 1                  view   1004258  2053013555631882655
# 2                  view   4600658  2053013563944993659
# 3                  view   1307350  2053013558920217191
# 4                  view   1002544  2053013555631882655
# ...                 ...       ...                  ...
# 23772862           view   1801141  2053013554415534427
# 23772863           view   4804294  2053013554658804075
# 23772864           view  28719425  2053013565639492569
# 23772865           view   1004833  2053013555631882655
# 23772866           view   2701706  2053013563911439225
#
#                              Category_Name    Brand  Price
# 0                appliances.kitchen.washer       lg  713.0
# 1                   electronics.smartphone    apple  732.0
# 2            appliances.kitchen.dishwasher  samsung  412.0
# 3                       computers.notebook     acer  515.0
# 4                   electronics.smartphone    apple  458.0
# ...                                    ...      ...    ...
# 23772862              electronics.video.tv    yasin  252.0
# 23772863       electronics.audio.headphone    meizu   64.0
# 23772864                     apparel.shoes    baden   63.0
# 23772865            electronics.smartphone  samsung  167.0
# 23772866  appliances.kitchen.refrigerators  samsung  566.0
#
# [23772867 rows x 10 columns]

# %%
visitor_id_counts = filtered_df['Visitor_ID'].value_counts()
visitor_id_counts
# Out:
# Visitor_ID
# 568778435    8829
# 512365995    5982
# 512475445    4799
# 568804062    4179
# 512388419    3646
#              ...
# 541717224       2
# 567130741       2
# 571499809       2
# 568961363       2
# 579967455       2
# Name: count, Length: 648550, dtype: int64

# %%
filtered_df['Visitor_Action'].value_counts()
# Out:
# Visitor_Action
# view        20999670
# cart         2114281
# purchase      658916
# Name: count, dtype: int64

# %%
# Check the memory usage of the filtered DataFrame in MB
memory_usage_mb = filtered_df.memory_usage(deep=True).sum() / (1024 * 1024)
print("Memory usage of filtered_df:", memory_usage_mb, "MB")
# Out:
# Memory usage of filtered_df: 5699.100270271301 MB

# %%
# Create a dictionary to map original category codes to their respective numeric labels
category_mapping = {category: label + 1 for label, category in enumerate(filtered_df['Product_Category'].unique())}

# Map the original category codes to their respective numeric labels and replace the values in the 'Product_Category' column
filtered_df['Product_Category'] = filtered_df['Product_Category'].map(category_mapping)

# Create a dictionary to map original Visitor IDs to their respective numeric labels
visitor_mapping = {visitor_id: label + 1 for label, visitor_id in enumerate(filtered_df['Visitor_ID'].unique())}

# Replace the original Visitor IDs with their respective numeric labels in the 'Visitor_ID' column
filtered_df['Visitor_ID'] = filtered_df['Visitor_ID'].map(visitor_mapping)

# Create a dictionary to map original products to their respective numeric labels
product_mapping = {product: label + 1 for label, product in enumerate(filtered_df['Product'].unique())}

# Replace the original products with their respective numeric labels in the 'Product' column
filtered_df['Product'] = filtered_df['Product'].map(product_mapping)

# Print the DataFrame with the replaced values
filtered_df
# Out:
#                          Timestamp  Day_of_Week  Day_of_Month  Visitor_ID  \
# 0        2019-11-01 00:00:01+00:00            4             1           1
# 1        2019-11-01 00:00:02+00:00            4             1           2
# 2        2019-11-01 00:00:05+00:00            4             1           3
# 3        2019-11-01 00:00:10+00:00            4             1           4
# 4        2019-11-01 00:00:14+00:00            4             1           5
# ...                            ...          ...           ...         ...
# 23772862 2019-11-30 23:59:49+00:00            5            30      359900
# 23772863 2019-11-30 23:59:53+00:00            5            30      126280
# 23772864 2019-11-30 23:59:58+00:00            5            30       53293
# 23772865 2019-11-30 23:59:59+00:00            5            30      640953
# 23772866 2019-11-30 23:59:59+00:00            5            30      101627
#
#          Visitor_Action  Product  Product_Category  \
# 0                  view        1                 1
# 1                  view        2                 2
# 2                  view        3                 3
# 3                  view        4                 4
# 4                  view        5                 2
# ...                 ...      ...               ...
# 23772862           view    11636                18
# 23772863           view      148                 8
# 23772864           view    20645                91
# 23772865           view      112                 2
# 23772866           view      810                 9
#
#                              Category_Name    Brand  Price
# 0                appliances.kitchen.washer       lg  713.0
# 1                   electronics.smartphone    apple  732.0
# 2            appliances.kitchen.dishwasher  samsung  412.0
# 3                       computers.notebook     acer  515.0
# 4                   electronics.smartphone    apple  458.0
# ...                                    ...      ...    ...
# 23772862              electronics.video.tv    yasin  252.0
# 23772863       electronics.audio.headphone    meizu   64.0
# 23772864                     apparel.shoes    baden   63.0
# 23772865            electronics.smartphone  samsung  167.0
# 23772866  appliances.kitchen.refrigerators  samsung  566.0
#
# [23772867 rows x 10 columns]

# %%
# Group the DataFrame by 'Category_Code' and aggregate 'Category_Name' as a set
category_groups = filtered_df.groupby('Product_Category')['Category_Name'].unique()

# Print the category names with the same category code
for Product_Category, Category_Name in category_groups.items():
    print(f"Category Code: {Product_Category}, Category Names: {Category_Name}")
# Out:
# Category Code: 1, Category Names: ['appliances.kitchen.washer']
# Category Code: 2, Category Names: ['electronics.smartphone']
# Category Code: 3, Category Names: ['appliances.kitchen.dishwasher']
# Category Code: 4, Category Names: ['computers.notebook']
# Category Code: 5, Category Names: ['appliances.environment.water_heater']
# Category Code: 6, Category Names: ['apparel.tshirt']
# Category Code: 7, Category Names: ['auto.accessories.compressor']
# Category Code: 8, Category Names: ['electronics.audio.headphone']
# Category Code: 9, Category Names: ['appliances.kitchen.refrigerators']
# Category Code: 10, Category Names: ['electronics.audio.subwoofer']
# Category Code: 11, Category Names: ['construction.tools.welding']
# Category Code: 12, Category Names: ['furniture.kitchen.table']
# Category Code: 13, Category Names: ['construction.tools.painting']
# Category Code: 14, Category Names: ['appliances.personal.massager']
# Category Code: 15, Category Names: ['furniture.kitchen.chair']
# Category Code: 16, Category Names: ['electronics.clocks']
# Category Code: 17, Category Names: ['computers.components.motherboard']
# Category Code: 18, Category Names: ['electronics.video.tv']
# Category Code: 19, Category Names: ['computers.desktop']
# Category Code: 20, Category Names: ['apparel.shirt']
# Category Code: 21, Category Names: ['apparel.shoes']
# Category Code: 22, Category Names: ['furniture.bedroom.bed']
# Category Code: 23, Category Names: ['sport.bicycle']
# Category Code: 24, Category Names: ['apparel.costume']
# Category Code: 25, Category Names: ['accessories.bag']
# Category Code: 26, Category Names: ['appliances.kitchen.hood']
# Category Code: 27, Category Names: ['electronics.audio.music_tools.piano']
# Category Code: 28, Category Names: ['computers.desktop']
# Category Code: 29, Category Names: ['apparel.shoes.keds']
# Category Code: 30, Category Names: ['apparel.shoes']
# Category Code: 31, Category Names: ['appliances.personal.massager']
# Category Code: 32, Category Names: ['apparel.shoes']
# Category Code: 33, Category Names: ['auto.accessories.player']
# Category Code: 34, Category Names: ['appliances.environment.vacuum']
# Category Code: 35, Category Names: ['computers.peripherals.printer']
# Category Code: 36, Category Names: ['electronics.clocks']
# Category Code: 37, Category Names: ['computers.peripherals.mouse']
# Category Code: 38, Category Names: ['computers.peripherals.monitor']
# Category Code: 39, Category Names: ['electronics.telephone']
# Category Code: 40, Category Names: ['appliances.iron']
# Category Code: 41, Category Names: ['furniture.living_room.sofa']
# Category Code: 42, Category Names: ['auto.accessories.alarm']
# Category Code: 43, Category Names: ['appliances.kitchen.microwave']
# Category Code: 44, Category Names: ['construction.tools.pump']
# Category Code: 45, Category Names: ['computers.peripherals.printer']
# Category Code: 46, Category Names: ['construction.tools.generator']
# Category Code: 47, Category Names: ['computers.components.videocards']
# Category Code: 48, Category Names: ['computers.desktop']
# Category Code: 49, Category Names: ['auto.accessories.videoregister']
# Category Code: 50, Category Names: ['apparel.shoes.ballet_shoes']
# Category Code: 51, Category Names: ['computers.components.power_supply']
# Category Code: 52, Category Names: ['kids.carriage']
# Category Code: 53, Category Names: ['appliances.kitchen.hob']
# Category Code: 54, Category Names: ['appliances.sewing_machine']
# Category Code: 55, Category Names: ['appliances.kitchen.oven']
# Category Code: 56, Category Names: ['appliances.kitchen.refrigerators']
# Category Code: 57, Category Names: ['appliances.kitchen.mixer']
# Category Code: 58, Category Names: ['construction.tools.generator']
# Category Code: 59, Category Names: ['appliances.kitchen.coffee_machine']
# Category Code: 60, Category Names: ['construction.tools.drill']
# Category Code: 61, Category Names: ['appliances.kitchen.refrigerators']
# Category Code: 62, Category Names: ['electronics.tablet']
# Category Code: 63, Category Names: ['kids.dolls']
# Category Code: 64, Category Names: ['appliances.environment.air_heater']
# Category Code: 65, Category Names: ['computers.components.cooler']
# Category Code: 66, Category Names: ['auto.accessories.parktronic']
# Category Code: 67, Category Names: ['kids.toys']
# Category Code: 68, Category Names: ['computers.peripherals.mouse']
# Category Code: 69, Category Names: ['auto.accessories.compressor']
# Category Code: 70, Category Names: ['electronics.audio.acoustic']
# Category Code: 71, Category Names: ['furniture.living_room.cabinet']
# Category Code: 72, Category Names: ['appliances.kitchen.blender']
# Category Code: 73, Category Names: ['accessories.wallet']
# Category Code: 74, Category Names: ['furniture.living_room.cabinet']
# Category Code: 75, Category Names: ['furniture.bedroom.bed']
# Category Code: 76, Category Names: ['kids.skates']
# Category Code: 77, Category Names: ['sport.trainer']
# Category Code: 78, Category Names: ['computers.peripherals.keyboard']
# Category Code: 79, Category Names: ['medicine.tools.tonometer']
# Category Code: 80, Category Names: ['sport.trainer']
# Category Code: 81, Category Names: ['construction.tools.drill']
# Category Code: 82, Category Names: ['electronics.video.tv']
# Category Code: 83, Category Names: ['accessories.bag']
# Category Code: 84, Category Names: ['appliances.kitchen.kettle']
# Category Code: 85, Category Names: ['kids.fmcg.diapers']
# Category Code: 86, Category Names: ['furniture.bedroom.bed']
# Category Code: 87, Category Names: ['computers.components.memory']
# Category Code: 88, Category Names: ['furniture.kitchen.table']
# Category Code: 89, Category Names: ['computers.components.cpu']
# Category Code: 90, Category Names: ['construction.components.faucet']
# Category Code: 91, Category Names: ['apparel.shoes']
# Category Code: 92, Category Names: ['appliances.kitchen.juicer']
# Category Code: 93, Category Names: ['apparel.shoes']
# Category Code: 94, Category Names: ['computers.desktop']
# Category Code: 95, Category Names: ['appliances.kitchen.coffee_grinder']
# Category Code: 96, Category Names: ['electronics.audio.microphone']
# Category Code: 97, Category Names: ['furniture.kitchen.table']
# Category Code: 98, Category Names: ['construction.tools.light']
# Category Code: 99, Category Names: ['furniture.living_room.chair']
# Category Code: 100, Category Names: ['furniture.kitchen.chair']
# Category Code: 101, Category Names: ['apparel.shoes']
# Category Code: 102, Category Names: ['electronics.camera.video']
# Category Code: 103, Category Names: ['electronics.audio.acoustic']
# Category Code: 104, Category Names: ['appliances.personal.scales']
# Category Code: 105, Category Names: ['apparel.shoes.keds']
# Category Code: 106, Category Names: ['apparel.jumper']
# Category Code: 107, Category Names: ['apparel.costume']
# Category Code: 108, Category Names: ['appliances.kitchen.meat_grinder']
# Category Code: 109, Category Names: ['computers.components.hdd']
# Category Code: 110, Category Names: ['sport.bicycle']
# Category Code: 111, Category Names: ['computers.ebooks']
# Category Code: 112, Category Names: ['electronics.audio.acoustic']
# Category Code: 113, Category Names: ['furniture.bathroom.toilet']
# Category Code: 114, Category Names: ['accessories.bag']
# Category Code: 115, Category Names: ['accessories.bag']
# Category Code: 116, Category Names: ['construction.tools.saw']
# Category Code: 117, Category Names: ['appliances.personal.hair_cutter']
# Category Code: 118, Category Names: ['appliances.kitchen.kettle']
# Category Code: 119, Category Names: ['construction.tools.saw']
# Category Code: 120, Category Names: ['construction.tools.saw']
# Category Code: 121, Category Names: ['appliances.environment.vacuum']
# Category Code: 122, Category Names: ['auto.accessories.winch']
# Category Code: 123, Category Names: ['appliances.environment.vacuum']
# Category Code: 124, Category Names: ['appliances.environment.air_conditioner']
# Category Code: 125, Category Names: ['computers.components.cooler']
# Category Code: 126, Category Names: ['apparel.dress']
# Category Code: 127, Category Names: ['appliances.kitchen.grill']
# Category Code: 128, Category Names: ['furniture.living_room.chair']
# Category Code: 129, Category Names: ['electronics.tablet']
# Category Code: 130, Category Names: ['apparel.underwear']
# Category Code: 131, Category Names: ['accessories.umbrella']
# Category Code: 132, Category Names: ['apparel.shirt']
# Category Code: 133, Category Names: ['appliances.ironing_board']
# Category Code: 134, Category Names: ['furniture.bedroom.pillow']
# Category Code: 135, Category Names: ['auto.accessories.anti_freeze']
# Category Code: 136, Category Names: ['apparel.shoes']
# Category Code: 137, Category Names: ['apparel.shoes']
# Category Code: 138, Category Names: ['apparel.shoes.keds']
# Category Code: 139, Category Names: ['apparel.shoes']
# Category Code: 140, Category Names: ['apparel.shoes']
# Category Code: 141, Category Names: ['apparel.shoes.slipons']
# Category Code: 142, Category Names: ['apparel.shoes']
# Category Code: 143, Category Names: ['apparel.underwear']
# Category Code: 144, Category Names: ['auto.accessories.radar']
# Category Code: 145, Category Names: ['apparel.shoes']
# Category Code: 146, Category Names: ['apparel.shoes']
# Category Code: 147, Category Names: ['apparel.shoes']
# Category Code: 148, Category Names: ['apparel.shoes']
# Category Code: 149, Category Names: ['sport.ski']
# Category Code: 150, Category Names: ['apparel.shoes.keds']
# Category Code: 151, Category Names: ['apparel.costume']
# Category Code: 152, Category Names: ['kids.toys']
# Category Code: 153, Category Names: ['kids.toys']
# Category Code: 154, Category Names: ['furniture.universal.light']
# Category Code: 155, Category Names: ['apparel.trousers']
# Category Code: 156, Category Names: ['furniture.bathroom.bath']
# Category Code: 157, Category Names: ['appliances.personal.scales']
# Category Code: 158, Category Names: ['construction.tools.light']
# Category Code: 159, Category Names: ['furniture.bedroom.blanket']
# Category Code: 160, Category Names: ['apparel.jeans']
# Category Code: 161, Category Names: ['appliances.kitchen.toster']
# Category Code: 162, Category Names: ['apparel.tshirt']
# Category Code: 163, Category Names: ['electronics.telephone']
# Category Code: 164, Category Names: ['furniture.bedroom.blanket']
# Category Code: 165, Category Names: ['apparel.shoes.moccasins']
# Category Code: 166, Category Names: ['stationery.cartrige']
# Category Code: 167, Category Names: ['accessories.bag']
# Category Code: 168, Category Names: ['sport.snowboard']
# Category Code: 169, Category Names: ['country_yard.cultivator']
# Category Code: 170, Category Names: ['sport.tennis']
# Category Code: 171, Category Names: ['apparel.scarf']
# Category Code: 172, Category Names: ['kids.swing']
# Category Code: 173, Category Names: ['electronics.camera.photo']
# Category Code: 174, Category Names: ['apparel.tshirt']
# Category Code: 175, Category Names: ['construction.tools.welding']
# Category Code: 176, Category Names: ['apparel.shoes.keds']
# Category Code: 177, Category Names: ['country_yard.lawn_mower']
# Category Code: 178, Category Names: ['electronics.video.projector']
# Category Code: 179, Category Names: ['sport.snowboard']
# Category Code: 180, Category Names: ['apparel.shoes.sandals']
# Category Code: 181, Category Names: ['appliances.environment.fan']
# Category Code: 182, Category Names: ['electronics.clocks']
# Category Code: 183, Category Names: ['construction.tools.light']
# Category Code: 184, Category Names: ['apparel.belt']
# Category Code: 185, Category Names: ['computers.notebook']
# Category Code: 186, Category Names: ['kids.swing']
# Category Code: 187, Category Names: ['auto.accessories.compressor']
# Category Code: 188, Category Names: ['appliances.kitchen.steam_cooker']
# Category Code: 189, Category Names: ['electronics.clocks']
# Category Code: 190, Category Names: ['apparel.shoes.slipons']
# Category Code: 191, Category Names: ['electronics.tablet']
# Category Code: 192, Category Names: ['apparel.shoes.moccasins']
# Category Code: 193, Category Names: ['apparel.shoes.keds']
# Category Code: 194, Category Names: ['accessories.bag']
# Category Code: 195, Category Names: ['appliances.kitchen.grill']
# Category Code: 196, Category Names: ['apparel.tshirt']
# Category Code: 197, Category Names: ['sport.bicycle']
# Category Code: 198, Category Names: ['apparel.shoes']
# Category Code: 199, Category Names: ['apparel.shorts']
# Category Code: 200, Category Names: ['sport.ski']
# Category Code: 201, Category Names: ['apparel.shoes']
# Category Code: 202, Category Names: ['apparel.shoes.sandals']
# Category Code: 203, Category Names: ['computers.peripherals.camera']
# Category Code: 204, Category Names: ['sport.bicycle']
# Category Code: 205, Category Names: ['apparel.shoes.sandals']
# Category Code: 206, Category Names: ['construction.tools.saw']
# Category Code: 207, Category Names: ['accessories.bag']
# Category Code: 208, Category Names: ['appliances.kitchen.kettle']
# Category Code: 209, Category Names: ['sport.bicycle']
# Category Code: 210, Category Names: ['apparel.shoes.moccasins']
# Category Code: 211, Category Names: ['apparel.trousers']
# Category Code: 212, Category Names: ['apparel.shoes']
# Category Code: 213, Category Names: ['apparel.sock']
# Category Code: 214, Category Names: ['sport.trainer']
# Category Code: 215, Category Names: ['apparel.shoes.sandals']
# Category Code: 216, Category Names: ['country_yard.furniture.hammok']
# Category Code: 217, Category Names: ['kids.skates']
# Category Code: 218, Category Names: ['apparel.shoes.espadrilles']
# Category Code: 219, Category Names: ['apparel.shoes']
# Category Code: 220, Category Names: ['sport.tennis']
# Category Code: 221, Category Names: ['apparel.shoes.step_ins']
# Category Code: 222, Category Names: ['apparel.shoes']
# Category Code: 223, Category Names: ['apparel.shoes.keds']
# Category Code: 224, Category Names: ['sport.snowboard']
# Category Code: 225, Category Names: ['appliances.kitchen.toster']
# Category Code: 226, Category Names: ['apparel.shoes.keds']
# Category Code: 227, Category Names: ['apparel.shoes.moccasins']
# Category Code: 228, Category Names: ['furniture.kitchen.table']
# Category Code: 229, Category Names: ['apparel.shoes']
# Category Code: 230, Category Names: ['apparel.shoes.sandals']
# Category Code: 231, Category Names: ['stationery.cartrige']
# Category Code: 232, Category Names: ['construction.tools.pump']
# Category Code: 233, Category Names: ['furniture.living_room.cabinet']
# Category Code: 234, Category Names: ['apparel.shoes.ballet_shoes']
# Category Code: 235, Category Names: ['appliances.environment.vacuum']
# Category Code: 236, Category Names: ['apparel.shoes']
# Category Code: 237, Category Names: ['apparel.shoes']
# Category Code: 238, Category Names: ['apparel.shirt']
# Category Code: 239, Category Names: ['apparel.costume']
# Category Code: 240, Category Names: ['apparel.glove']
# Category Code: 241, Category Names: ['apparel.skirt']
# Category Code: 242, Category Names: ['apparel.dress']
# Category Code: 243, Category Names: ['apparel.costume']
# Category Code: 244, Category Names: ['furniture.living_room.cabinet']
# Category Code: 245, Category Names: ['apparel.costume']
# Category Code: 246, Category Names: ['apparel.shirt']
# Category Code: 247, Category Names: ['apparel.shoes']
# Category Code: 248, Category Names: ['construction.tools.welding']
# Category Code: 249, Category Names: ['construction.tools.soldering']
# Category Code: 250, Category Names: ['apparel.glove']
# Category Code: 251, Category Names: ['sport.trainer']
# Category Code: 252, Category Names: ['apparel.glove']
# Category Code: 253, Category Names: ['apparel.skirt']
# Category Code: 254, Category Names: ['country_yard.furniture.bench']
# Category Code: 255, Category Names: ['apparel.shoes']
# Category Code: 256, Category Names: ['apparel.costume']
# Category Code: 257, Category Names: ['sport.bicycle']
# Category Code: 258, Category Names: ['sport.ski']
# Category Code: 259, Category Names: ['apparel.jumper']
# Category Code: 260, Category Names: ['apparel.trousers']
# Category Code: 261, Category Names: ['apparel.shirt']
# Category Code: 262, Category Names: ['apparel.jumper']
# Category Code: 263, Category Names: ['construction.tools.screw']
# Category Code: 264, Category Names: ['appliances.kitchen.fryer']
# Category Code: 265, Category Names: ['apparel.shirt']

# %%
# Step 1: Split the strings under the 'Category_Name' column by each '.'
split_columns = filtered_df['Category_Name'].str.split('.')

# Step 2: Assign a unique numerical value to each unique word
unique_words = set(word for row in split_columns for word in row)
word_to_num = {word: i+1 for i, word in enumerate(unique_words)}

# Step 3: Combine unique numerical values for each word to form a new numerical code for each initial unique full string
numerical_codes = split_columns.apply(lambda row: '.'.join(str(word_to_num[word]) for word in row))

# Add the new numerical codes as a new column in the DataFrame
filtered_df['Category_Name_Numeric'] = numerical_codes

# Print the DataFrame with the new numerical codes
filtered_df
# Out:
#                          Timestamp  Day_of_Week  Day_of_Month  Visitor_ID  \
# 0        2019-11-01 00:00:01+00:00            4             1           1
# 1        2019-11-01 00:00:02+00:00            4             1           2
# 2        2019-11-01 00:00:05+00:00            4             1           3
# 3        2019-11-01 00:00:10+00:00            4             1           4
# 4        2019-11-01 00:00:14+00:00            4             1           5
# ...                            ...          ...           ...         ...
# 23772862 2019-11-30 23:59:49+00:00            5            30      359900
# 23772863 2019-11-30 23:59:53+00:00            5            30      126280
# 23772864 2019-11-30 23:59:58+00:00            5            30       53293
# 23772865 2019-11-30 23:59:59+00:00            5            30      640953
# 23772866 2019-11-30 23:59:59+00:00            5            30      101627
#
#          Visitor_Action  Product  Product_Category  \
# 0                  view        1                 1
# 1                  view        2                 2
# 2                  view        3                 3
# 3                  view        4                 4
# 4                  view        5                 2
# ...                 ...      ...               ...
# 23772862           view    11636                18
# 23772863           view      148                 8
# 23772864           view    20645                91
# 23772865           view      112                 2
# 23772866           view      810                 9
#
#                              Category_Name    Brand  Price  \
# 0                appliances.kitchen.washer       lg  713.0
# 1                   electronics.smartphone    apple  732.0
# 2            appliances.kitchen.dishwasher  samsung  412.0
# 3                       computers.notebook     acer  515.0
# 4                   electronics.smartphone    apple  458.0
# ...                                    ...      ...    ...
# 23772862              electronics.video.tv    yasin  252.0
# 23772863       electronics.audio.headphone    meizu   64.0
# 23772864                     apparel.shoes    baden   63.0
# 23772865            electronics.smartphone  samsung  167.0
# 23772866  appliances.kitchen.refrigerators  samsung  566.0
#
#          Category_Name_Numeric
# 0                    43.60.104
# 1                        64.80
# 2                     43.60.58
# 3                        50.89
# 4                        64.80
# ...                        ...
# 23772862             64.71.108
# 23772863              64.26.68
# 23772864                110.97
# 23772865                 64.80
# 23772866             43.60.136
#
# [23772867 rows x 11 columns]

# %%
num_to_word = {v: k for k, v in word_to_num.items()}
num_to_word
# Out:
# {1: 'compressor',
#  2: 'air_conditioner',
#  3: 'anti_freeze',
#  4: 'cpu',
#  5: 'juicer',
#  6: 'grill',
#  7: 'tonometer',
#  8: 'fryer',
#  9: 'toilet',
#  10: 'skirt',
#  11: 'faucet',
#  12: 'sock',
#  13: 'umbrella',
#  14: 'microwave',
#  15: 'oven',
#  16: 'peripherals',
#  17: 'ballet_shoes',
#  18: 'cooler',
#  19: 'blanket',
#  20: 'sandals',
#  21: 'personal',
#  22: 'skates',
#  23: 'cabinet',
#  24: 'generator',
#  25: 'bag',
#  26: 'audio',
#  27: 'step_ins',
#  28: 'massager',
#  29: 'bathroom',
#  30: 'videocards',
#  31: 'coffee_machine',
#  32: 'camera',
#  33: 'table',
#  34: 'scarf',
#  35: 'projector',
#  36: 'environment',
#  37: 'vacuum',
#  38: 'hood',
#  39: 'bath',
#  40: 'photo',
#  41: 'steam_cooker',
#  42: 'monitor',
#  43: 'appliances',
#  44: 'painting',
#  45: 'bicycle',
#  46: 'pump',
#  47: 'tablet',
#  48: 'dress',
#  49: 'chair',
#  50: 'computers',
#  51: 'trousers',
#  52: 'shorts',
#  53: 'screw',
#  54: 'iron',
#  55: 'moccasins',
#  56: 'meat_grinder',
#  57: 'coffee_grinder',
#  58: 'dishwasher',
#  59: 'living_room',
#  60: 'kitchen',
#  61: 'shirt',
#  62: 'construction',
#  63: 'scales',
#  64: 'electronics',
#  65: 'motherboard',
#  66: 'drill',
#  67: 'country_yard',
#  68: 'headphone',
#  69: 'glove',
#  70: 'hair_cutter',
#  71: 'video',
#  72: 'tools',
#  73: 'welding',
#  74: 'keds',
#  75: 'subwoofer',
#  76: 'water_heater',
#  77: 'underwear',
#  78: 'accessories',
#  79: 'dolls',
#  80: 'smartphone',
#  81: 'winch',
#  82: 'diapers',
#  83: 'cartrige',
#  84: 'memory',
#  85: 'ebooks',
#  86: 'power_supply',
#  87: 'tshirt',
#  88: 'desktop',
#  89: 'notebook',
#  90: 'mixer',
#  91: 'jeans',
#  92: 'videoregister',
#  93: 'medicine',
#  94: 'trainer',
#  95: 'slipons',
#  96: 'keyboard',
#  97: 'shoes',
#  98: 'costume',
#  99: 'belt',
#  100: 'furniture',
#  101: 'fmcg',
#  102: 'sport',
#  103: 'kettle',
#  104: 'washer',
#  105: 'components',
#  106: 'lawn_mower',
#  107: 'pillow',
#  108: 'tv',
#  109: 'wallet',
#  110: 'apparel',
#  111: 'hdd',
#  112: 'music_tools',
#  113: 'sofa',
#  114: 'auto',
#  115: 'kids',
#  116: 'clocks',
#  117: 'hammok',
#  118: 'air_heater',
#  119: 'player',
#  120: 'piano',
#  121: 'tennis',
#  122: 'telephone',
#  123: 'ironing_board',
#  124: 'bench',
#  125: 'toster',
#  126: 'alarm',
#  127: 'printer',
#  128: 'cultivator',
#  129: 'acoustic',
#  130: 'fan',
#  131: 'saw',
#  132: 'snowboard',
#  133: 'parktronic',
#  134: 'bed',
#  135: 'bedroom',
#  136: 'refrigerators',
#  137: 'blender',
#  138: 'swing',
#  139: 'jumper',
#  140: 'mouse',
#  141: 'sewing_machine',
#  142: 'universal',
#  143: 'microphone',
#  144: 'espadrilles',
#  145: 'hob',
#  146: 'carriage',
#  147: 'toys',
#  148: 'ski',
#  149: 'soldering',
#  150: 'light',
#  151: 'stationery',
#  152: 'radar'}

# %%
filtered_df['Category_Name_Numeric'].value_counts()
# Out:
# Category_Name_Numeric
# 64.80         9559280
# 64.71.108     1287215
# 50.89         1207901
# 64.26.68      1090105
# 64.116         995302
#                ...
# 110.97.144        487
# 110.52            214
# 62.72.53           61
# 43.60.8            48
# 67.100.124          1
# Name: count, Length: 128, dtype: int64

# %%
#Dropping Category_Name 
Redefined_df= filtered_df.drop(columns='Category_Name')

# %%
Redefined_df = Redefined_df[['Timestamp','Day_of_Week','Day_of_Month','Visitor_ID','Visitor_Action','Product','Product_Category','Category_Name_Numeric','Brand','Price']]
Redefined_df
# Out:
#                          Timestamp  Day_of_Week  Day_of_Month  Visitor_ID  \
# 0        2019-11-01 00:00:01+00:00            4             1           1
# 1        2019-11-01 00:00:02+00:00            4             1           2
# 2        2019-11-01 00:00:05+00:00            4             1           3
# 3        2019-11-01 00:00:10+00:00            4             1           4
# 4        2019-11-01 00:00:14+00:00            4             1           5
# ...                            ...          ...           ...         ...
# 23772862 2019-11-30 23:59:49+00:00            5            30      359900
# 23772863 2019-11-30 23:59:53+00:00            5            30      126280
# 23772864 2019-11-30 23:59:58+00:00            5            30       53293
# 23772865 2019-11-30 23:59:59+00:00            5            30      640953
# 23772866 2019-11-30 23:59:59+00:00            5            30      101627
#
#          Visitor_Action  Product  Product_Category Category_Name_Numeric  \
# 0                  view        1                 1             43.60.104
# 1                  view        2                 2                 64.80
# 2                  view        3                 3              43.60.58
# 3                  view        4                 4                 50.89
# 4                  view        5                 2                 64.80
# ...                 ...      ...               ...                   ...
# 23772862           view    11636                18             64.71.108
# 23772863           view      148                 8              64.26.68
# 23772864           view    20645                91                110.97
# 23772865           view      112                 2                 64.80
# 23772866           view      810                 9             43.60.136
#
#             Brand  Price
# 0              lg  713.0
# 1           apple  732.0
# 2         samsung  412.0
# 3            acer  515.0
# 4           apple  458.0
# ...           ...    ...
# 23772862    yasin  252.0
# 23772863    meizu   64.0
# 23772864    baden   63.0
# 23772865  samsung  167.0
# 23772866  samsung  566.0
#
# [23772867 rows x 10 columns]

# %%
# Define mapping of original values of Visitor_Action to unique numerical values
action_mapping = {'view': 1, 'cart': 2, 'purchase': 3}

# Replace values in the 'Visitor_Action' column with numerical values
Redefined_df['Visitor_Action'] = Redefined_df['Visitor_Action'].map(action_mapping)

# Print the DataFrame with numerical values
Redefined_df
# Out:
#                          Timestamp  Day_of_Week  Day_of_Month  Visitor_ID  \
# 0        2019-11-01 00:00:01+00:00            4             1           1
# 1        2019-11-01 00:00:02+00:00            4             1           2
# 2        2019-11-01 00:00:05+00:00            4             1           3
# 3        2019-11-01 00:00:10+00:00            4             1           4
# 4        2019-11-01 00:00:14+00:00            4             1           5
# ...                            ...          ...           ...         ...
# 23772862 2019-11-30 23:59:49+00:00            5            30      359900
# 23772863 2019-11-30 23:59:53+00:00            5            30      126280
# 23772864 2019-11-30 23:59:58+00:00            5            30       53293
# 23772865 2019-11-30 23:59:59+00:00            5            30      640953
# 23772866 2019-11-30 23:59:59+00:00            5            30      101627
#
#           Visitor_Action  Product  Product_Category Category_Name_Numeric  \
# 0                      1        1                 1             43.60.104
# 1                      1        2                 2                 64.80
# 2                      1        3                 3              43.60.58
# 3                      1        4                 4                 50.89
# 4                      1        5                 2                 64.80
# ...                  ...      ...               ...                   ...
# 23772862               1    11636                18             64.71.108
# 23772863               1      148                 8              64.26.68
# 23772864               1    20645                91                110.97
# 23772865               1      112                 2                 64.80
# 23772866               1      810                 9             43.60.136
#
#             Brand  Price
# 0              lg  713.0
# 1           apple  732.0
# 2         samsung  412.0
# 3            acer  515.0
# 4           apple  458.0
# ...           ...    ...
# 23772862    yasin  252.0
# 23772863    meizu   64.0
# 23772864    baden   63.0
# 23772865  samsung  167.0
# 23772866  samsung  566.0
#
# [23772867 rows x 10 columns]

# %%
# Extract hour component from 'Timestamp' column
Redefined_df['Hour_of_Day'] = Redefined_df['Timestamp'].dt.hour

Resized_df= Redefined_df.drop(columns='Timestamp')
Resized_df = Resized_df[['Hour_of_Day','Day_of_Week','Day_of_Month','Visitor_ID','Visitor_Action','Product','Product_Category','Category_Name_Numeric','Brand','Price']]
Resized_df
# Out:
#           Hour_of_Day  Day_of_Week  Day_of_Month  Visitor_ID  Visitor_Action  \
# 0                   0            4             1           1               1
# 1                   0            4             1           2               1
# 2                   0            4             1           3               1
# 3                   0            4             1           4               1
# 4                   0            4             1           5               1
# ...               ...          ...           ...         ...             ...
# 23772862           23            5            30      359900               1
# 23772863           23            5            30      126280               1
# 23772864           23            5            30       53293               1
# 23772865           23            5            30      640953               1
# 23772866           23            5            30      101627               1
#
#           Product  Product_Category Category_Name_Numeric    Brand  Price
# 0               1                 1             43.60.104       lg  713.0
# 1               2                 2                 64.80    apple  732.0
# 2               3                 3              43.60.58  samsung  412.0
# 3               4                 4                 50.89     acer  515.0
# 4               5                 2                 64.80    apple  458.0
# ...           ...               ...                   ...      ...    ...
# 23772862    11636                18             64.71.108    yasin  252.0
# 23772863      148                 8              64.26.68    meizu   64.0
# 23772864    20645                91                110.97    baden   63.0
# 23772865      112                 2                 64.80  samsung  167.0
# 23772866      810                 9             43.60.136  samsung  566.0
#
# [23772867 rows x 10 columns]

# %%
# Check the memory usage of the filtered DataFrame in MB
memory_usage_mb = Resized_df.memory_usage(deep=True).sum() / (1024 * 1024)
print("Memory usage of Resized_df:", memory_usage_mb, "MB")
# Out:
# Memory usage of Resized_df: 4043.1280250549316 MB

# %%
Resized_df['Product'].value_counts()
# Out:
# Product
# 59       424462
# 84       406393
# 122      351898
# 172      281333
# 202      199696
#           ...
# 58197         1
# 58194         1
# 45856         1
# 58191         1
# 64095         1
# Name: count, Length: 64095, dtype: int64

# %%
#Filter the DataFrame to include only "view" events
view_df = Resized_df[Resized_df['Visitor_Action'] == 1]

# Group by 'Visitor_ID' and count the number of products viewed by each visitor
products_viewed_by_visitor = view_df.groupby('Visitor_ID')['Product'].count()

# Sum the counts of products viewed by all visitors
total_products_viewed = products_viewed_by_visitor.sum()

# Get the total number of unique visitors
total_visitors = Resized_df['Visitor_ID'].nunique()

# Calculate the formula
Avg_P_W_V = total_products_viewed / total_visitors

print("Total products viewed:", total_products_viewed)
print("Total number of visitors:", total_visitors)
print("Average products viewed per visitor:", Avg_P_W_V)
# Out:
# Total products viewed: 20999670
# Total number of visitors: 648550
# Average products viewed per visitor: 32.37941561945879

# %%
# Count the number of apprearance of each product
product_counts = Resized_df['Product'].value_counts()

# Filter out products that have been appeared an average of 35 times throughout the month
products_to_keep = product_counts[product_counts > 34].index

#Filter the original DataFrame
Resized_filt_df = Resized_df[Resized_df['Product'].isin(products_to_keep)]

Resized_filt_df['Product'].value_counts()
# Out:
# Product
# 59       424462
# 84       406393
# 122      351898
# 172      281333
# 202      199696
#           ...
# 52806        35
# 23025        35
# 23032        35
# 3495         35
# 14816        35
# Name: count, Length: 30191, dtype: int64

# %%
Resized_filt_df = Resized_filt_df.reset_index(drop=True)
Resized_filt_df
# Out:
#           Hour_of_Day  Day_of_Week  Day_of_Month  Visitor_ID  Visitor_Action  \
# 0                   0            4             1           1               1
# 1                   0            4             1           2               1
# 2                   0            4             1           3               1
# 3                   0            4             1           4               1
# 4                   0            4             1           5               1
# ...               ...          ...           ...         ...             ...
# 23394187           23            5            30      359900               1
# 23394188           23            5            30      126280               1
# 23394189           23            5            30       53293               1
# 23394190           23            5            30      640953               1
# 23394191           23            5            30      101627               1
#
#           Product  Product_Category Category_Name_Numeric    Brand  Price
# 0               1                 1             43.60.104       lg  713.0
# 1               2                 2                 64.80    apple  732.0
# 2               3                 3              43.60.58  samsung  412.0
# 3               4                 4                 50.89     acer  515.0
# 4               5                 2                 64.80    apple  458.0
# ...           ...               ...                   ...      ...    ...
# 23394187    11636                18             64.71.108    yasin  252.0
# 23394188      148                 8              64.26.68    meizu   64.0
# 23394189    20645                91                110.97    baden   63.0
# 23394190      112                 2                 64.80  samsung  167.0
# 23394191      810                 9             43.60.136  samsung  566.0
#
# [23394192 rows x 10 columns]

# %%
# Filter the DataFrame to include only "purchase" events
purchase_df = Resized_filt_df[Resized_filt_df['Visitor_Action'] == 3]

# Calculate total revenue by summing up the 'Price' values for purchase events
total_revenue = purchase_df['Price'].sum()

print("Total revenue:", total_revenue)

# Calculate the average product price across all products
average_product_price = Resized_filt_df['Price'].mean()

print("Average Product Price Across All Products:", average_product_price)
# Out:
# Total revenue: 241105765.0
# Average Product Price Across All Products: 357.9878592943069

# %%
# Filter the DataFrame for rows where Price is between 1 and 9 and Visitor_Action is 'purchase'
P_1_9 = Resized_filt_df[(Resized_filt_df['Price'] >= 1) & (Resized_filt_df['Price'] <= 9) & (Resized_filt_df['Visitor_Action'] == 3)]
# Calculate the total revenue from the filtered DataFrame
P_1_9_tot = P_1_9['Price'].sum()
print("Total contribution of the purchased product where Price is between 1 and 9 to total revenue is:", P_1_9_tot,"at" ,round(P_1_9_tot/total_revenue*100, 3), "%")
# Out:
# Total contribution of the purchased product where Price is between 1 and 9 to total revenue is: 27979.0 at 0.012 %

# %%
# Filter the original DataFrame to exclude rows in P_1_9
Resized_filt2_df = Resized_filt_df[Resized_filt_df['Price'] > 9]
Resized_filt2_df = Resized_filt2_df.reset_index(drop=True)
Resized_filt2_df
# Out:
#           Hour_of_Day  Day_of_Week  Day_of_Month  Visitor_ID  Visitor_Action  \
# 0                   0            4             1           1               1
# 1                   0            4             1           2               1
# 2                   0            4             1           3               1
# 3                   0            4             1           4               1
# 4                   0            4             1           5               1
# ...               ...          ...           ...         ...             ...
# 23237680           23            5            30      359900               1
# 23237681           23            5            30      126280               1
# 23237682           23            5            30       53293               1
# 23237683           23            5            30      640953               1
# 23237684           23            5            30      101627               1
#
#           Product  Product_Category Category_Name_Numeric    Brand  Price
# 0               1                 1             43.60.104       lg  713.0
# 1               2                 2                 64.80    apple  732.0
# 2               3                 3              43.60.58  samsung  412.0
# 3               4                 4                 50.89     acer  515.0
# 4               5                 2                 64.80    apple  458.0
# ...           ...               ...                   ...      ...    ...
# 23237680    11636                18             64.71.108    yasin  252.0
# 23237681      148                 8              64.26.68    meizu   64.0
# 23237682    20645                91                110.97    baden   63.0
# 23237683      112                 2                 64.80  samsung  167.0
# 23237684      810                 9             43.60.136  samsung  566.0
#
# [23237685 rows x 10 columns]

# %%
Resized_filt2_df['Price'].max()
# Out:
# 2574.0

# %%
Resized_filt2_df.dtypes
# Out:
# Hour_of_Day                int32
# Day_of_Week                int32
# Day_of_Month               int32
# Visitor_ID                 int64
# Visitor_Action             int64
# Product                    int64
# Product_Category           int64
# Category_Name_Numeric     object
# Brand                     object
# Price                    float64
# dtype: object

# %%
#Making datatype more efficient in terms of storage space 
# Convert Hour_of_Day, Day_of_Week, Day_of_Month to uint8
Resized_filt2_df['Hour_of_Day'] = Resized_filt2_df['Hour_of_Day'].astype('uint8')
Resized_filt2_df['Day_of_Week'] = Resized_filt2_df['Day_of_Week'].astype('uint8')
Resized_filt2_df['Day_of_Month'] = Resized_filt2_df['Day_of_Month'].astype('uint8')

# Convert Visitor_Action to uint8 since it has only 3 unique values
Resized_filt2_df['Visitor_Action'] = Resized_filt2_df['Visitor_Action'].astype('uint8')

# Convert Visitor_ID, Product, Product_Category to uint32
Resized_filt2_df['Visitor_ID'] = Resized_filt2_df['Visitor_ID'].astype('uint32')
Resized_filt2_df['Product'] = Resized_filt2_df['Product'].astype('uint32')
Resized_filt2_df['Product_Category'] = Resized_filt2_df['Product_Category'].astype('uint32')

# Convert Price to uint16 since it has values up to 2574
Resized_filt2_df['Price'] = Resized_filt2_df['Price'].astype('uint16')

# Convert Category_Name_Numeric and Brand to category type
Resized_filt2_df['Category_Name_Numeric'] = Resized_filt2_df['Category_Name_Numeric'].astype('category')
Resized_filt2_df['Brand'] = Resized_filt2_df['Brand'].astype('category')

# Print the updated data types
Resized_filt2_df.dtypes
# Out:
# Hour_of_Day                 uint8
# Day_of_Week                 uint8
# Day_of_Month                uint8
# Visitor_ID                 uint32
# Visitor_Action              uint8
# Product                    uint32
# Product_Category           uint32
# Category_Name_Numeric    category
# Brand                    category
# Price                      uint16
# dtype: object

# %%
# Check the memory usage of the filtered DataFrame in MB
memory_usage_mb = Resized_filt2_df.memory_usage(deep=True).sum() / (1024 * 1024)
print("Memory usage of Resized_filt2_df:", memory_usage_mb, "MB")
# Out:
# Memory usage of Resized_filt2_df: 465.5119981765747 MB

# %%
# Save the modified DataFrame to a new CSV file
Resized_filt2_df.to_csv('Resources/DF_Resized.csv', index=False, encoding='utf-8')

# %%
#Calculating KPIs and analysis based on final cleaned DF

#Filter the DataFrame to include only "view" events
view_df2 = Resized_filt2_df[Resized_filt2_df['Visitor_Action'] == 1]

# Group by 'Visitor_ID' and count the number of products viewed by each visitor
products_viewed_by_visitor2 = view_df2.groupby('Visitor_ID')['Product'].count()

# Sum the counts of products viewed by all visitors
total_products_viewed2 = products_viewed_by_visitor2.sum()

# Get the total number of unique visitors
total_visitors2 = Resized_filt2_df['Visitor_ID'].nunique()

# Calculate the formula
Avg_P_W_V2 = np.ceil(total_products_viewed2 / total_visitors2)

# Filter the DataFrame to include only "purchase" events
purchase_df2 = Resized_filt2_df[Resized_filt2_df['Visitor_Action'] == 3]
total_orders = len(purchase_df2)

# Calculate total revenue by summing up the 'Price' values for purchase events
total_revenue2 = purchase_df2['Price'].sum()

# Calculate the average product price across all products
aop = np.ceil(Resized_filt2_df['Price'].mean())

# Calculate the Average Order Value (AOV)
aov = np.ceil((total_revenue2 / total_orders) * 100)

# Calculate the number of unique users who made a purchase
num_purchases = purchase_df2['Visitor_ID'].nunique()

# Calculate the Conversion Rate (CVR %) 
cvr = np.ceil((num_purchases / total_visitors2) * 100)

# Group the DataFrame by visitor_id and count the number of purchases
purchase_counts = purchase_df2.groupby('Visitor_ID').size()

# Filter the DataFrame to include only visitor_id with two or more purchases
return_clients = purchase_counts[purchase_counts >= 2]

# Calculate the percentage of return clients
percentage_return_clients = np.ceil((len(return_clients) / Resized_filt2_df['Visitor_ID'].nunique()) * 100)

# Filter the DataFrame to include only events related to shopping carts created
cart_created_df = Resized_filt2_df[Resized_filt2_df['Visitor_Action'] == 2]

# Count the total number of shopping carts created
num_shopping_carts_created = len(cart_created_df)

# Calculate the Shopping Cart Abandonment Rate
shopping_cart_abandonment_rate = np.ceil((total_orders / num_shopping_carts_created) * 100)

print("Total products viewed:", total_products_viewed2)
print("Total number of visitors:", total_visitors2)
print("Total number of orders:", total_orders)
print("Average products viewed per visitor:", Avg_P_W_V2)
print("Total revenue:", total_revenue2)
print("Average Product Price Across All Products:", aop)
print("Average Value of Purchase Transaction:", aov)
print("Conversion Rate (CVR):", cvr)
print("Shopping Cart Abandonment Rate:", shopping_cart_abandonment_rate)
print("Percentage of return clients with two or more purchases:", percentage_return_clients)
# Out:
# Total products viewed: 20493555
# Total number of visitors: 647455
# Total number of orders: 652966
# Average products viewed per visitor: 32.0
# Total revenue: 241077786
# Average Product Price Across All Products: 361.0
# Average Value of Purchase Transaction: 36921.0
# Conversion Rate (CVR): 51.0
# Shopping Cart Abandonment Rate: 32.0
# Percentage of return clients with two or more purchases: 19.0

# %%
# Top 5 Highest Grossing Products

grossing_products = purchase_df2.groupby('Product')['Price'].sum().sort_values(ascending=False).head(5)

# Top 5 Products by Conversion Rates
purchase_counts = purchase_df2.groupby('Product').size()
view_counts = Resized_filt2_df[Resized_filt2_df['Visitor_Action'] == 1].groupby('Product').size()
Top10_CVR = (purchase_counts / view_counts).sort_values(ascending=False).head(5)

# Group the DataFrame by product category and sum the prices to calculate total revenue for each category
category_revenue = Resized_filt2_df.groupby('Product_Category')['Price'].sum().reset_index()

# Sort the categories by total revenue in descending order
top_5_categories = category_revenue.sort_values(by='Price', ascending=False).head(5)
print("\nTop 5 Highest Grossing Products:")
print(grossing_products)
print("\nTop 5 Products by Conversion Rates:")
print(Top10_CVR)
print("\nTop 5 Product Categories by Total Revenue:")
print(top_5_categories)
# Out:
# Top 5 Highest Grossing Products:
# Product
# 59     20606392
# 124    11437701
# 53      7079799
# 190     6813467
# 5       5597573
# Name: Price, dtype: uint64
#
# Top 5 Products by Conversion Rates:
# Product
# 40688    0.276923
# 5272     0.250000
# 4816     0.238095
# 53028    0.217391
# 57671    0.212121
# dtype: float64
#
# Top 5 Product Categories by Total Revenue:
#     Product_Category       Price
# 1                  2  4574324905
# 3                  4   850192043
# 17                18   586426534
# 0                  1   274956903
# 8                  9   231766668

# %%
# Filter the main DataFrame to include only products belonging to the top 5 categories
top_products = Resized_filt2_df[Resized_filt2_df['Product_Category'].isin(top_5_categories['Product_Category'])]

# Group the top products DataFrame by product category and sort each group by price to get top products within each category
top_products = top_products.groupby('Product_Category').apply(lambda x: x.nlargest(1, 'Price')).reset_index(drop=True)

# Reverse the mapping dictionary to map numerical codes back to original Category_Name strings
num_to_category_name = {v: k for k, v in word_to_num.items()}

# Retrieve the original Category_Name associated with the top products
top_products['Category_Name'] = top_products['Category_Name_Numeric'].apply(lambda x: '.'.join(num_to_category_name[int(num)] for num in x.split('.')))

# Print the top products with their associated original Category_Name
print(top_products[['Product', 'Category_Name']])
# Out:
#    Product                     Category_Name
# 0    34038         appliances.kitchen.washer
# 1    42732            electronics.smartphone
# 2    11588                computers.notebook
# 3    17275  appliances.kitchen.refrigerators
# 4     1580              electronics.video.tv
# /var/folders/bf/0vmhxl6x4xn54k_fw54k_rkr0000gn/T/ipykernel_50134/3891696463.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_products = top_products.groupby('Product_Category').apply(lambda x: x.nlargest(1, 'Price')).reset_index(drop=True)

# %%
# Group by Hour_of_Day, Day_of_Week, and Day_of_Month for views
hourly_views = view_df2.groupby('Hour_of_Day').size()
daily_views = view_df2.groupby('Day_of_Week').size()
monthly_views = view_df2.groupby('Day_of_Month').size()

# Group by Hour_of_Day, Day_of_Week, and Day_of_Month for purchases
hourly_purchases = purchase_df2.groupby('Hour_of_Day').size()
daily_purchases = purchase_df2.groupby('Day_of_Week').size()
monthly_purchases = purchase_df2.groupby('Day_of_Month').size()

# Find the top 3 hour, day of the week, and day of the month with the highest number of views and purchases
max_hourly_views = hourly_views.nlargest(3)
max_daily_views = daily_views.nlargest(3)
max_monthly_views = monthly_views.nlargest(3)

max_hourly_purchases = hourly_purchases.nlargest(3)
max_daily_purchases = daily_purchases.nlargest(3)
max_monthly_purchases = monthly_purchases.nlargest(3)

# Print results
print(f"Hour of the day with the highest number of views: {max_hourly_views}")
print(f"Day of the week with the highest number of views: {max_daily_views}")
print(f"Day of the month with the highest number of views: {max_monthly_views}")
print(f"Hour of the day with the highest number of purchases: {max_hourly_purchases}")
print(f"Day of the week with the highest number of purchases: {max_daily_purchases}")
print(f"Day of the month with the highest number of purchases: {max_monthly_purchases}")
# Out:
# Hour of the day with the highest number of views: Hour_of_Day
# 16    1314042
# 17    1307106
# 15    1297075
# dtype: int64
# Day of the week with the highest number of views: Day_of_Week
# 4    4387365
# 5    4212072
# 6    3705646
# dtype: int64
# Day of the month with the highest number of views: Day_of_Month
# 15    2616329
# 16    2473428
# 17    2362833
# dtype: int64
# Hour of the day with the highest number of purchases: Hour_of_Day
# 9     51634
# 10    50021
# 8     46856
# dtype: int64
# Day of the week with the highest number of purchases: Day_of_Week
# 6    181946
# 5    119353
# 4     75510
# dtype: int64
# Day of the month with the highest number of purchases: Day_of_Month
# 17    133602
# 16     50865
# 29     24049
# dtype: int64

# %%
import sqlalchemy
from sqlalchemy import create_engine, text, func
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import Session
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import inspect
import altair as alt
import json
import os
