# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
import calendar

# %%
# Read data into a Pandas DataFrame
merged_df=pd.read_csv('Resources/sample_tableau_30m.csv', encoding='utf-8')
merged_df.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-11-01 05:23:11 UTC       view     1004317  2053013555631882655
# 1  2019-11-02 06:18:53 UTC       view     1005174  2053013555631882655
# 2  2019-11-22 14:30:13 UTC       view     3700779  2053013565983425517
# 3  2019-11-08 18:02:49 UTC       view     2702700  2053013563911439225
# 4  2019-11-30 16:13:09 UTC       view     1004870  2053013555631882655
#
#                       category_code    brand    price    user_id
# 0            electronics.smartphone    meizu   159.26  513395491
# 1            electronics.smartphone  samsung   643.23  532847621
# 2     appliances.environment.vacuum   xiaomi   295.76  550765008
# 3  appliances.kitchen.refrigerators    midea  1029.60  548415316
# 4            electronics.smartphone  samsung   282.89  513752448

# %%
visitor_id_counts = merged_df['user_id'].value_counts()
visitor_id_counts
# Out:
# user_id
# 597644399    15739
# 569335945     6767
# 568804062     6214
# 637360772     3943
# 625149076     3935
#              ...
# 600709285        1
# 603765853        1
# 603124640        1
# 606153445        1
# 647277668        1
# Name: count, Length: 6263923, dtype: int64

# %%
# Renaming columns
df_cleaned = merged_df.rename(columns={
    'event_time': 'Timestamp',
    'event_type': 'Visitor_Action',
    'product_id': 'Product',
    'category_id': 'Product_Category',
    'category_code': 'Category_Name',
    'brand': 'Brand',
    'price': 'Price',
    'user_id': 'Visitor_ID'
})
df_cleaned
# Out:
#                         Timestamp Visitor_Action    Product  \
# 0         2019-11-01 05:23:11 UTC           view    1004317
# 1         2019-11-02 06:18:53 UTC           view    1005174
# 2         2019-11-22 14:30:13 UTC           view    3700779
# 3         2019-11-08 18:02:49 UTC           view    2702700
# 4         2019-11-30 16:13:09 UTC           view    1004870
# ...                           ...            ...        ...
# 29999995  2020-04-27 04:34:07 UTC           view   10900392
# 29999996  2020-04-19 03:22:38 UTC           view   52900028
# 29999997  2020-04-21 10:02:05 UTC           view    1004839
# 29999998  2020-04-26 01:33:05 UTC           view    2501614
# 29999999  2020-04-13 18:24:07 UTC           view  100025343
#
#              Product_Category                     Category_Name    Brand  \
# 0         2053013555631882655            electronics.smartphone    meizu
# 1         2053013555631882655            electronics.smartphone  samsung
# 2         2053013565983425517     appliances.environment.vacuum   xiaomi
# 3         2053013563911439225  appliances.kitchen.refrigerators    midea
# 4         2053013555631882655            electronics.smartphone  samsung
# ...                       ...                               ...      ...
# 29999995  2232732105912091273          appliances.kitchen.mixer    vitek
# 29999996  2232732095568937384                     sport.trainer  stanley
# 29999997  2232732093077520756          construction.tools.light     oppo
# 29999998  2232732092565815652           appliances.kitchen.oven  redmond
# 29999999  2053013562149831447         furniture.universal.light  serebro
#
#             Price  Visitor_ID
# 0          159.26   513395491
# 1          643.23   532847621
# 2          295.76   550765008
# 3         1029.60   548415316
# 4          282.89   513752448
# ...           ...         ...
# 29999995   102.94   590911528
# 29999996    84.94   542124965
# 29999997   160.08   539384386
# 29999998   154.42   647277668
# 29999999    11.58   558817474
#
# [30000000 rows x 8 columns]

# %%
# Get unique user IDs with "view" events
view_users = df_cleaned[df_cleaned['Visitor_Action'] == 'view']['Visitor_ID'].unique()

# Get unique user IDs with "cart" or "purchase" events
cart_purchase_users = df_cleaned[df_cleaned['Visitor_Action'].isin(['cart', 'purchase'])]['Visitor_ID'].unique()

# Find user IDs with both "view" and "cart" or "purchase" events
view_and_cart_purchase_users = set(view_users) & set(cart_purchase_users)

# Filter the dataset to include only rows for user IDs with both "view" and "cart" or "purchase" events
filtered_df = df_cleaned[df_cleaned['Visitor_ID'].isin(view_and_cart_purchase_users)]

filtered_df = filtered_df.reset_index(drop=True)

# Print the filtered DataFrame
filtered_df
# Out:
#                         Timestamp Visitor_Action    Product  \
# 0         2019-11-22 14:30:13 UTC           view    3700779
# 1         2019-11-16 08:47:08 UTC           cart    1004833
# 2         2019-11-23 10:10:16 UTC           view   21402079
# 3         2019-11-29 08:34:48 UTC           view    1801704
# 4         2019-11-15 15:02:09 UTC           view   22400054
# ...                           ...            ...        ...
# 12028190  2020-04-28 08:26:36 UTC           view  100112241
# 12028191  2020-04-26 08:38:32 UTC           view    1004259
# 12028192  2020-04-03 15:11:39 UTC           view  100086203
# 12028193  2020-04-21 10:02:05 UTC           view    1004839
# 12028194  2020-04-13 18:24:07 UTC           view  100025343
#
#              Product_Category                  Category_Name    Brand   Price  \
# 0         2053013565983425517  appliances.environment.vacuum   xiaomi  295.76
# 1         2053013555631882655         electronics.smartphone  samsung  179.16
# 2         2053013561579406073             electronics.clocks    lorus  102.19
# 3         2053013554415534427           electronics.video.tv  samsung  385.83
# 4         2053013554474254687   electronics.audio.microphone    trust   15.16
# ...                       ...                            ...      ...     ...
# 12028190  2053013551932506308       construction.tools.drill    escan   69.24
# 12028191  2232732093077520756       construction.tools.light    apple  823.44
# 12028192  2232732093077520756       construction.tools.light  samsung  103.45
# 12028193  2232732093077520756       construction.tools.light     oppo  160.08
# 12028194  2053013562149831447      furniture.universal.light  serebro   11.58
#
#           Visitor_ID
# 0          550765008
# 1          562112994
# 2          514759577
# 3          563926853
# 4          517410481
# ...              ...
# 12028190   513039757
# 12028191   560848082
# 12028192   512519873
# 12028193   539384386
# 12028194   558817474
#
# [12028195 rows x 8 columns]

# %%
# Converting event_time to datetime
try:
    filtered_df['Timestamp'] = pd.to_datetime(filtered_df['Timestamp'], format='%Y-%m-%d %H:%M:%S %Z', errors='coerce')
except Exception as e:
    print("Error during conversion:", e)

# %%
# Print data types of each column
print("Data types of each column:")
print(filtered_df.dtypes)
print()
# Out:
# Data types of each column:
# Timestamp           datetime64[ns, UTC]
# Visitor_Action                   object
# Product                           int64
# Product_Category                  int64
# Category_Name                    object
# Brand                            object
# Price                           float64
# Visitor_ID                        int64
# dtype: object

# %%
# Extract day of the week (Monday=0, Sunday=6) and day of the month
filtered_df.loc[:, 'Day_of_Week'] = filtered_df['Timestamp'].dt.dayofweek
filtered_df.loc[:, 'Day_of_Month'] = filtered_df['Timestamp'].dt.day
filtered_df.loc[:, 'Month'] = filtered_df['Timestamp'].dt.month
filtered_df.loc[:, 'Hour_of_Day'] = filtered_df['Timestamp'].dt.hour

filtered_df = filtered_df[['Hour_of_Day','Timestamp','Day_of_Week','Day_of_Month','Month','Visitor_ID','Visitor_Action','Product','Product_Category','Category_Name','Brand','Price']]

# Define mapping of numerical values of Day_of_Week to actual day names
day_mapping = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

# Map the numeric day of week to day names
filtered_df['Day_of_Week'] = filtered_df['Day_of_Week'].map(day_mapping)
filtered_df
# Out:
#           Hour_of_Day                 Timestamp Day_of_Week  Day_of_Month  \
# 0                  14 2019-11-22 14:30:13+00:00      Friday            22
# 1                   8 2019-11-16 08:47:08+00:00    Saturday            16
# 2                  10 2019-11-23 10:10:16+00:00    Saturday            23
# 3                   8 2019-11-29 08:34:48+00:00      Friday            29
# 4                  15 2019-11-15 15:02:09+00:00      Friday            15
# ...               ...                       ...         ...           ...
# 12028190            8 2020-04-28 08:26:36+00:00     Tuesday            28
# 12028191            8 2020-04-26 08:38:32+00:00      Sunday            26
# 12028192           15 2020-04-03 15:11:39+00:00      Friday             3
# 12028193           10 2020-04-21 10:02:05+00:00     Tuesday            21
# 12028194           18 2020-04-13 18:24:07+00:00      Monday            13
#
#           Month  Visitor_ID Visitor_Action    Product     Product_Category  \
# 0            11   550765008           view    3700779  2053013565983425517
# 1            11   562112994           cart    1004833  2053013555631882655
# 2            11   514759577           view   21402079  2053013561579406073
# 3            11   563926853           view    1801704  2053013554415534427
# 4            11   517410481           view   22400054  2053013554474254687
# ...         ...         ...            ...        ...                  ...
# 12028190      4   513039757           view  100112241  2053013551932506308
# 12028191      4   560848082           view    1004259  2232732093077520756
# 12028192      4   512519873           view  100086203  2232732093077520756
# 12028193      4   539384386           view    1004839  2232732093077520756
# 12028194      4   558817474           view  100025343  2053013562149831447
#
#                           Category_Name    Brand   Price
# 0         appliances.environment.vacuum   xiaomi  295.76
# 1                electronics.smartphone  samsung  179.16
# 2                    electronics.clocks    lorus  102.19
# 3                  electronics.video.tv  samsung  385.83
# 4          electronics.audio.microphone    trust   15.16
# ...                                 ...      ...     ...
# 12028190       construction.tools.drill    escan   69.24
# 12028191       construction.tools.light    apple  823.44
# 12028192       construction.tools.light  samsung  103.45
# 12028193       construction.tools.light     oppo  160.08
# 12028194      furniture.universal.light  serebro   11.58
#
# [12028195 rows x 12 columns]

# %%
#Dropping user_session 
filtered_df = filtered_df.drop(columns='Timestamp')
filtered_df
# Out:
#           Hour_of_Day Day_of_Week  Day_of_Month  Month  Visitor_ID  \
# 0                  14      Friday            22     11   550765008
# 1                   8    Saturday            16     11   562112994
# 2                  10    Saturday            23     11   514759577
# 3                   8      Friday            29     11   563926853
# 4                  15      Friday            15     11   517410481
# ...               ...         ...           ...    ...         ...
# 12028190            8     Tuesday            28      4   513039757
# 12028191            8      Sunday            26      4   560848082
# 12028192           15      Friday             3      4   512519873
# 12028193           10     Tuesday            21      4   539384386
# 12028194           18      Monday            13      4   558817474
#
#          Visitor_Action    Product     Product_Category  \
# 0                  view    3700779  2053013565983425517
# 1                  cart    1004833  2053013555631882655
# 2                  view   21402079  2053013561579406073
# 3                  view    1801704  2053013554415534427
# 4                  view   22400054  2053013554474254687
# ...                 ...        ...                  ...
# 12028190           view  100112241  2053013551932506308
# 12028191           view    1004259  2232732093077520756
# 12028192           view  100086203  2232732093077520756
# 12028193           view    1004839  2232732093077520756
# 12028194           view  100025343  2053013562149831447
#
#                           Category_Name    Brand   Price
# 0         appliances.environment.vacuum   xiaomi  295.76
# 1                electronics.smartphone  samsung  179.16
# 2                    electronics.clocks    lorus  102.19
# 3                  electronics.video.tv  samsung  385.83
# 4          electronics.audio.microphone    trust   15.16
# ...                                 ...      ...     ...
# 12028190       construction.tools.drill    escan   69.24
# 12028191       construction.tools.light    apple  823.44
# 12028192       construction.tools.light  samsung  103.45
# 12028193       construction.tools.light     oppo  160.08
# 12028194      furniture.universal.light  serebro   11.58
#
# [12028195 rows x 11 columns]

# %%
# Identify rows where Category_Name contains "construction" and the brand is either "apple" or "samsung", then change the brand to "Others"
filtered_df.loc[(filtered_df['Category_Name'].str.contains('construction', case=False)) & (filtered_df['Brand'].isin(['apple', 'samsung','oppo', 'xiaomi', 'huawei'])), 'Brand'] = 'Others'
filtered_df
# Out:
#           Hour_of_Day Day_of_Week  Day_of_Month  Month  Visitor_ID  \
# 0                  14      Friday            22     11   550765008
# 1                   8    Saturday            16     11   562112994
# 2                  10    Saturday            23     11   514759577
# 3                   8      Friday            29     11   563926853
# 4                  15      Friday            15     11   517410481
# ...               ...         ...           ...    ...         ...
# 12028190            8     Tuesday            28      4   513039757
# 12028191            8      Sunday            26      4   560848082
# 12028192           15      Friday             3      4   512519873
# 12028193           10     Tuesday            21      4   539384386
# 12028194           18      Monday            13      4   558817474
#
#          Visitor_Action    Product     Product_Category  \
# 0                  view    3700779  2053013565983425517
# 1                  cart    1004833  2053013555631882655
# 2                  view   21402079  2053013561579406073
# 3                  view    1801704  2053013554415534427
# 4                  view   22400054  2053013554474254687
# ...                 ...        ...                  ...
# 12028190           view  100112241  2053013551932506308
# 12028191           view    1004259  2232732093077520756
# 12028192           view  100086203  2232732093077520756
# 12028193           view    1004839  2232732093077520756
# 12028194           view  100025343  2053013562149831447
#
#                           Category_Name    Brand   Price
# 0         appliances.environment.vacuum   xiaomi  295.76
# 1                electronics.smartphone  samsung  179.16
# 2                    electronics.clocks    lorus  102.19
# 3                  electronics.video.tv  samsung  385.83
# 4          electronics.audio.microphone    trust   15.16
# ...                                 ...      ...     ...
# 12028190       construction.tools.drill    escan   69.24
# 12028191       construction.tools.light   Others  823.44
# 12028192       construction.tools.light   Others  103.45
# 12028193       construction.tools.light   Others  160.08
# 12028194      furniture.universal.light  serebro   11.58
#
# [12028195 rows x 11 columns]

# %%
# Define a dictionary mapping numeric values to text
replacement_dict = {
    1: 'Jan-2020',
    2: 'Feb-2020',
    3: 'Mar-2020',
    4: 'Apr-2020',
    11: 'Nov-2019',
    12: 'Dec-2019',
}

# Apply the replacement to the 'Month' column
filtered_df['Month'] = filtered_df['Month'].replace(replacement_dict)

# %%
filtered_df
# Out:
#           Hour_of_Day Day_of_Week  Day_of_Month     Month  Visitor_ID  \
# 0                  14      Friday            22  Nov-2019   550765008
# 1                   8    Saturday            16  Nov-2019   562112994
# 2                  10    Saturday            23  Nov-2019   514759577
# 3                   8      Friday            29  Nov-2019   563926853
# 4                  15      Friday            15  Nov-2019   517410481
# ...               ...         ...           ...       ...         ...
# 12028190            8     Tuesday            28  Apr-2020   513039757
# 12028191            8      Sunday            26  Apr-2020   560848082
# 12028192           15      Friday             3  Apr-2020   512519873
# 12028193           10     Tuesday            21  Apr-2020   539384386
# 12028194           18      Monday            13  Apr-2020   558817474
#
#          Visitor_Action    Product     Product_Category  \
# 0                  view    3700779  2053013565983425517
# 1                  cart    1004833  2053013555631882655
# 2                  view   21402079  2053013561579406073
# 3                  view    1801704  2053013554415534427
# 4                  view   22400054  2053013554474254687
# ...                 ...        ...                  ...
# 12028190           view  100112241  2053013551932506308
# 12028191           view    1004259  2232732093077520756
# 12028192           view  100086203  2232732093077520756
# 12028193           view    1004839  2232732093077520756
# 12028194           view  100025343  2053013562149831447
#
#                           Category_Name    Brand   Price
# 0         appliances.environment.vacuum   xiaomi  295.76
# 1                electronics.smartphone  samsung  179.16
# 2                    electronics.clocks    lorus  102.19
# 3                  electronics.video.tv  samsung  385.83
# 4          electronics.audio.microphone    trust   15.16
# ...                                 ...      ...     ...
# 12028190       construction.tools.drill    escan   69.24
# 12028191       construction.tools.light   Others  823.44
# 12028192       construction.tools.light   Others  103.45
# 12028193       construction.tools.light   Others  160.08
# 12028194      furniture.universal.light  serebro   11.58
#
# [12028195 rows x 11 columns]

# %%
# Mapping of month abbreviations to month numbers
month_mapping = {
    'Jan-2020': 1,
    'Feb-2020': 2,
    'Mar-2020': 3,
    'Apr-2020': 4,
    'Nov-2019': 11,
    'Dec-2019': 12
}

# Sample 1 million rows per month
sampled_dfs = []
for month_abbr, month_num in month_mapping.items():
    month_df = filtered_df[filtered_df['Month'] == month_abbr]
    sampled_df = month_df.sample(n=min(1000000, len(month_df)), replace=False, random_state=42)
    sampled_dfs.append(sampled_df)

# Concatenate the sampled DataFrames
sampled_df = pd.concat(sampled_dfs)

# Display the sampled DataFrame
print(sampled_df)
# Out:
#          Hour_of_Day Day_of_Week  Day_of_Month     Month  Visitor_ID  \
# 5198059           18      Friday            17  Jan-2020   523723855
# 4716385           14      Friday            31  Jan-2020   513631028
# 4726983            8      Friday             3  Jan-2020   558618462
# 5465811            6      Friday            31  Jan-2020   607840104
# 4524172           17   Wednesday             1  Jan-2020   557545137
# ...              ...         ...           ...       ...         ...
# 3099925           14    Thursday            19  Dec-2019   568520034
# 3049284           13      Monday             2  Dec-2019   514051064
# 2670287           11    Saturday             7  Dec-2019   545244966
# 2958151           17      Sunday             8  Dec-2019   542217176
# 2356149           10   Wednesday            18  Dec-2019   535930047
#
#         Visitor_Action    Product     Product_Category  \
# 5198059           view    1305232  2053013554658804075
# 4716385           cart    1005105  2232732093077520756
# 4726983           view    1004856  2232732093077520756
# 5465811           view    4804056  2232732079706079299
# 4524172           view  100052011  2053013554658804075
# ...                ...        ...                  ...
# 3099925           view    1004872  2232732093077520756
# 3049284           view    7900404  2232732097775141341
# 2670287           view    1201504  2232732101407408685
# 2958151       purchase    3601438  2232732092297380188
# 2356149           view    2701731  2232732091718566220
#
#                             Category_Name    Brand    Price
# 5198059       electronics.audio.headphone       hp  2123.50
# 4716385          construction.tools.light   Others  1208.00
# 4726983          construction.tools.light   Others   135.73
# 5465811                     sport.bicycle    apple   150.75
# 4524172       electronics.audio.headphone       hp   336.95
# ...                                   ...      ...      ...
# 3099925          construction.tools.light   Others   282.84
# 3049284                apparel.shoes.keds    selby    38.59
# 2670287             apparel.shoes.slipons  samsung   149.90
# 2958151         appliances.kitchen.washer     beko   216.20
# 2356149  appliances.kitchen.refrigerators       lg  1012.90
#
# [6000000 rows x 11 columns]

# %%
# Save the modified DataFrame to a new CSV file
sampled_df.to_csv('Resources/sample_tableau_6m.csv', index=False, encoding='utf-8')
